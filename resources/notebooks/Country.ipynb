# %% [markdown]
# # File Country

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("Explore").getOrCreate()

# %%
base_path = "../../data/input/"
df = spark.read.csv(base_path + "WDICountry.csv", header=True, inferSchema=True, multiLine=True).drop("_c30")
# df = spark.read.csv(base_path + "WDICountry.csv", header=True, quote='"', mode="DROPMALFORMED").drop("_c30")

df.limit(10).toPandas()
#df.printSchema()
# Out:
#   Country Code                   Short Name                   Table Name  \
# 0          ABW                        Aruba                        Aruba
# 1          AFE  Africa Eastern and Southern  Africa Eastern and Southern
# 2          AFG                  Afghanistan                  Afghanistan
# 3          AFW   Africa Western and Central   Africa Western and Central
# 4          AGO                       Angola                       Angola
# 5          ALB                      Albania                      Albania
# 6          AND                      Andorra                      Andorra
# 7          ARB                   Arab World                   Arab World
# 8          ARE         United Arab Emirates         United Arab Emirates
# 9          ARG                    Argentina                    Argentina
#
#                       Long Name 2-alpha code   Currency Unit  \
# 0                         Aruba           AW   Aruban florin
# ...
